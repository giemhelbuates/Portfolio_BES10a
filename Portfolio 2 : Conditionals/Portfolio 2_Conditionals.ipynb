# %% [markdown]
# # Portfolio 2 - Conditionals

# %% [markdown]
# #### GIEMHEL A. BUATES     -   BSChE-1A

# %% [markdown]
# ## Program 1: Study Break Recommendation Checker

# %% [markdown]
# #### Write a program to promt the user to enter the number of hours they studied and determine the recommended break activity

# %% [markdown]
# ##### Prompt the user to enter their name

# %%
name = input("Enter your name: ") #Stores the student's name
# Out:
# Enter your name:  Giemhel

# %%
print ("Hello,", name) #Displays a welcome message
# Out:
# Hello, Giemhel

# %% [markdown]
# ##### Prompt the user to enter study hours

# %%
study_hours = int(input("Enter your study hours today: ")) #Stores study hours
# Out:
# Enter your study hours today:  2

# %% [markdown]
# ##### Display study hours

# %%
print ("Study Hours:", study_hours) #Displays entered study hours
# Out:
# Study Hours: 2

# %% [markdown]
# ##### Conditional Statements

# %%
if study_hours <= 2:
    print("You can study a little more.") #Displayed is study hours are low
elif study_hours <= 5: 
    print("Take a short break and drink water.") #Displayed if study hours are moderate
else:
    print("You deserve a long rest or sleep.") #Dsiplayed if study hours are high
# Out:
# You can study a little more.

# %% [markdown]
# ##### Prompt the user to enter study hours

# %%
study_hours = int(input("Enter your study hours today: ")) #Stores study hours
# Out:
# Enter your study hours today:  4

# %% [markdown]
# ##### Display study hours

# %%
print ("Study Hours:", study_hours) #Displays entered study hours
# Out:
# Study Hours: 4

# %%
if study_hours <= 2:
    print("You can study a little more.") #Displayed is study hours are low
elif study_hours <= 5: 
    print("Take a short break and drink water.") #Displayed if study hours are moderate
else:
    print("You deserve a long rest or sleep.") #Dsiplayed if study hours are high
# Out:
# Take a short break and drink water.

# %% [markdown]
# ##### Prompt the user to enter study hours

# %%
study_hours = int(input("Enter your study hours today: ")) #Stores study hours
# Out:
# Enter your study hours today:  8

# %% [markdown]
# ##### Display study hours

# %%
print ("Study Hours:", study_hours) #Displays entered study hours
# Out:
# Study Hours: 8

# %%
if study_hours <= 2:
    print("You can study a little more.") #Displayed is study hours are low
elif study_hours <= 5: 
    print("Take a short break and drink water.") #Displayed if study hours are moderate
else:
    print("You deserve a long rest or sleep.") #Dsiplayed if study hours are high
# Out:
# You deserve a long rest or sleep.

# %%
print ("Program is Finished") # Displays the end of the program
# Out:
# Program is Finished

# %% [markdown]
# ### This program checks the number of hours a student studied and recommends an actiity for their break

# %% [markdown]
# ## Program 2: Social Battery Checker

# %% [markdown]
# #### Write a program to prompt the user to enter their social battery percentage and determine if they still have energy to socialize.

# %% [markdown]
# ##### Prompt the user to enter social battery percentage

# %%
battery = int(input("Enter your social battery percentage: ")) #Stores battery percentage
# Out:
# Enter your social battery percentage:  70

# %% [markdown]
# ##### Dsiplay social battery percentage

# %%
print("Social Battery percentage:", battery) #Dsiplays the entered percentage
# Out:
# Social Battery percentage: 70

# %% [markdown]
# ##### Conditional Statement

# %%
if battery >= 50:
    print ("You still have energy to socialize!") #Displayed if battery is high
else:
    print("You need rest and alone time.") #Displayed if battery is low
# Out:
# You still have energy to socialize!

# %%
battery = int(input("Enter your social battery percentage: ")) #Stores battery percentage
# Out:
# Enter your social battery percentage:  30

# %% [markdown]
# ##### Dsiplay social battery percentage

# %%
print("Social Battery percentage:", battery) #Dsiplays the entered percentage
# Out:
# Social Battery percentage: 30

# %%
if battery >= 50:
    print ("You still have energy to socialize!") #Displayed if battery is high
else:
    print("You need rest and alone time.") #Displayed if battery is low
# Out:
# You need rest and alone time.

# %%
print ("Program is Finished") # Displays the end of the program
# Out:
# Program is Finished

# %% [markdown]
# ### This program checks if the student still has enough social energy after classes and activities. It demonstrates how conditionals can be applied to realistic student experiences such as social energy.

# %% [markdown]
# ## Program 3: Fast Food Line Patience Checker

# %% [markdown]
# #### Write a program to promp the user to enter the number of people in a fast food line and determine the person's reaction

# %%
#Prompt the user to enter the number of people in line
people = int(input("Enter the number of people in the fast food line: ")) #Stores the number of people in line

#Dsiplay the number of people
print ("People in Line:", people) #Display the entered number

#Conditional Statements
if people <= 5:
    print("The line is short. You can order quickly.") #Displayed if line is short
elif people <=15:
    print("The line is manageable. Waiting is still okay.") #Displayed if line is moderate
else:
    print("The line is too long. Maybe eat somewhere elese.") #Displayed if line is long
# Out:
# Enter the number of people in the fast food line:  4
# People in Line: 4
# The line is short. You can order quickly.

# %%
#Prompt the user to enter the number of people in line
people = int(input("Enter the number of people in the fast food line: ")) #Stores the number of people in line

#Dsiplay the number of people
print ("People in Line:", people) #Display the entered number

#Conditional Statements
if people <= 5:
    print("The line is short. You can order quickly.") #Displayed if line is short
elif people <=15:
    print("The line is manageable. Waiting is still okay.") #Displayed if line is moderate
else:
    print("The line is too long. Maybe eat somewhere elese.") #Displayed if line is long
# Out:
# Enter the number of people in the fast food line:  11
# People in Line: 11
# The line is manageable. Waiting is still okay.

# %%
#Prompt the user to enter the number of people in line
people = int(input("Enter the number of people in the fast food line: ")) #Stores the number of people in line

#Dsiplay the number of people
print ("People in Line:", people) #Display the entered number

#Conditional Statements
if people <= 5:
    print("The line is short. You can order quickly.") #Displayed if line is short
elif people <=15:
    print("The line is manageable. Waiting is still okay.") #Displayed if line is moderate
else:
    print("The line is too long. Maybe eat somewhere elese.") #Displayed if line is lonG
# Out:
# Enter the number of people in the fast food line:  25
# People in Line: 25
# The line is too long. Maybe eat somewhere elese.

# %% [markdown]
# ### This program demonstrates how conditional statements can be applied to real-life situations such as deciding whether to wait in a fast food line.

# %% [markdown]
# ## Program 4: Phone Battery Checker

# %% [markdown]
# #### Write a program to prompt the user to enter their phone battery percentage and determine the suggested action

# %%
# Prompt the user to enter phone battery percentage
battery = int(input("Enter your phone battery percentage: ")) #Stores battery percentage

#Dsiplay battery percentage
print("Battery Percentage:", battery) #Displays entered battery percentage

#Conditional Statements
if battery >= 70:
    print("Your phone batteyr is high.") #Displayed if battery is high
elif battery >= 30:
    print("Your battery is moderate. Bring your charger just in case.") #Displayed if batter is moderate
else:
    print("Your battery is low. Charge your phone now.") #Displayed if battery is low
# Out:
# Enter your phone battery percentage:  16
# Battery Percentage: 16
# Your battery is low. Charge your phone now.

# %%
# Prompt the user to enter phone battery percentage
battery = int(input("Enter your phone battery percentage: ")) #Stores battery percentage

#Dsiplay battery percentage
print("Battery Percentage:", battery) #Displays entered battery percentage

#Conditional Statements
if battery >= 70:
    print("Your phone batteyr is high.") #Displayed if battery is high
elif battery >= 30:
    print("Your battery is moderate. Bring your charger just in case.") #Displayed if batter is moderate
else:
    print("Your battery is low. Charge your phone now.") #Displayed if battery is low
# Out:
# Enter your phone battery percentage:  37
# Battery Percentage: 37
# Your battery is moderate. Bring your charger just in case.

# %% [markdown]
# ### This program checks phone battery percentage and suggests what action they should do.
