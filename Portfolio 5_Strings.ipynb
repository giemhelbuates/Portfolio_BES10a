# %% [markdown]
# # Portfolio 5: Strings

# %% [markdown]
# ## GIEMHEL A. BUATES  - BSChE 1A

# %% [markdown]
# ### Program 1: Typing Style Analyzer

# %% [markdown]
# #### Create a program that uses strings to analyze a chat message and determine if the typing style looks calm, excited or angry.

# %% [markdown]
# ##### Prompt the user to enter a message

# %%
message = input("Enter a chat message: ") #Stores the message
print ("Chat message:", message)
Check_message = message.lower() #Converts message into lowercase
# Out:
# Enter a chat message:  OMG THIS IS AMAZING !!!
# Chat message: OMG THIS IS AMAZING !!!

# %% [markdown]
# ##### Initial Values

# %%
excitement = 0 #Counts exxclamation marks
anger = 0 #Counts uppercase letters

# %% [markdown]
# ##### Loop through every character

# %%
for character in message:
    #Checks for exclamation marks
    if character == "!":
        excitement = excitement + 1

    #Checks for uppercase letters
    elif character in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
        anger = anger + 1

# %% [markdown]
# ##### Determines typing style

# %%
if excitement >=3:
    print ("Typing Style:Very Excited") #Displayed if many exclamation marks are found
elif anger >=5:
    print ("Typing Style: Angry") # Displayed if many uppercase letters are found
else:
    print ("Typing Style: Calm") #Displayed if styping style is normal
# Out:
# Typing Style:Very Excited

# %% [markdown]
# ##### Try some more

# %%
message = input("Enter a chat message: ") #Stores the message
print ("Chat message:", message)
Check_message = message.lower() #Converts message into lowercase

excitement = 0 #Counts exxclamation marks
anger = 0 #Counts uppercase letters

for character in message:
    #Checks for exclamation marks
    if character == "!":
        excitement = excitement + 1

    #Checks for uppercase letters
    elif character in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
        anger = anger + 1

if excitement >=3:
    print ("Typing Style:Very Excited") #Displayed if many exclamation marks are found
elif anger >=5:
    print ("Typing Style: Angry") # Displayed if many uppercase letters are found
else:
    print ("Typing Style: Calm") #Displayed if styping style is normal
# Out:
# Enter a chat message:  WHAT THE HECK IS HAPPENING HERE!?
# Chat message: WHAT THE HECK IS HAPPENING HERE!?
# Typing Style: Angry

# %%
message = input("Enter a chat message: ") #Stores the message
print ("Chat message:", message)
Check_message = message.lower() #Converts message into lowercase

excitement = 0 #Counts exxclamation marks
anger = 0 #Counts uppercase letters

for character in message:
    #Checks for exclamation marks
    if character == "!":
        excitement = excitement + 1

    #Checks for uppercase letters
    elif character in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
        anger = anger + 1

if excitement >=3:
    print ("Typing Style:Very Excited") #Displayed if many exclamation marks are found
elif anger >=5:
    print ("Typing Style: Angry") # Displayed if many uppercase letters are found
else:
    print ("Typing Style: Calm") #Displayed if styping style is normal
# Out:
# Enter a chat message:  hello, how are you
# Chat message: hello, how are you
# Typing Style: Calm

# %%
print ("Program is Finished") #Displays the end of the program
# Out:
# Program is Finished

# %% [markdown]
# #### *This program uses string operations to analyze typing styles based on symbols and letter patterns found in a message.*

# %% [markdown]
# ### Program 2: Suspicious Chat Detector

# %% [markdown]
# #### Create a program that uses strings to check if a chat message contains suspicious or scam-related words.

# %%
# Prompt the user to enter a message
message = input ("Enter a chat message: ") #Stores the message
print("Chat message:", message) #Display the entered chat message
check_message = message.lower() #Converts message into lowercase

#Checks for suspicious words
if "you won" in check_message:
    print ("Warning: Suspicious word detected!") #Displayed if 'winner' is found
elif "password" in check_message:
    print ("Warning: Sensitive word detected!") #Displayed if 'password' is found
elif "free money" in check_message:
    print ("Warning: Scam-like message detected!") #Displayed if 'free money' is found
else: print("Message looks safe.") #Displayed if no suspicious word is found
# Out:
# Enter a chat message:  Congratulations! You won a lottery ticket today!
# Chat message: Congratulations! You won a lottery ticket today!
# ...

# %%
# Prompt the user to enter a message
message = input ("Enter a chat message: ") #Stores the message
print("Chat message:", message) #Display the entered chat message
check_message = message.lower() #Converts message into lowercase

#Checks for suspicious words
if "you won" in check_message:
    print ("Warning: Suspicious word detected!") #Displayed if 'winner' is found
elif "password" in check_message:
    print ("Warning: Sensitive word detected!") #Displayed if 'password' is found
elif "free money" in check_message:
    print ("Warning: Scam-like message detected!") #Displayed if 'free money' is found
else: print("Message looks safe.") #Displayed if no suspicious word is found
# Out:
# Enter a chat message:  To claim your free money, log in through the link below.
# Chat message: To claim your free money, log in through the link below.
# ...

# %%
print ("Program is Finished") #Displays the end of the program
# Out:
# Program is Finished

# %% [markdown]
# #### *This program uses string operations to check if a message contains suspicious words commonly found in scam or fake messages.*
